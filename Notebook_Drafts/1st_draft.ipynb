# %%
import pandas as pd

# %%
survey_df = pd.read_csv('kaggle_survey_2021_responses.csv')
survey_df
# Out:
# C:\Users\zaina\AppData\Local\Temp\ipykernel_20992\272820903.py:1: DtypeWarning: Columns (0,18,32,49,56,69,88,100,107,113,139,184,195,201,202,253,266,278,283,285,286,287,288,289,290,291,292,301,322,339,347,355,367) have mixed types. Specify dtype option on import or set low_memory=False.
#   survey_df = pd.read_csv('kaggle_survey_2021_responses.csv')
#       Time from Start to Finish (seconds)                           Q1  \
# 0                   Duration (in seconds)  What is your age (# years)?
# 1                                     910                        50-54
# 2                                     784                        50-54
# 3                                     924                        22-24
# 4                                     575                        45-49
# ...                                   ...                          ...
# 25969                                1756                        30-34
# ...

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25974 entries, 0 to 25973
# Columns: 369 entries, Time from Start to Finish (seconds) to Q38_B_OTHER
# dtypes: object(369)
# memory usage: 73.1+ MB

# %%
survey_df.dtypes
# Out:
# Time from Start to Finish (seconds)    object
# Q1                                     object
# Q2                                     object
# Q3                                     object
# Q4                                     object
#                                         ...
# Q38_B_Part_8                           object
# Q38_B_Part_9                           object
# Q38_B_Part_10                          object
# Q38_B_Part_11                          object
# Q38_B_OTHER                            object
# Length: 369, dtype: object

# %%
survey_df = pd.DataFrame(survey_df)
survey_df
# Out:
#       Time from Start to Finish (seconds)                           Q1  \
# 0                   Duration (in seconds)  What is your age (# years)?
# 1                                     910                        50-54
# 2                                     784                        50-54
# 3                                     924                        22-24
# 4                                     575                        45-49
# ...                                   ...                          ...
# 25969                                1756                        30-34
# 25970                                 253                        22-24
# 25971                                 494                        50-54
# 25972                                 277                        45-49
# 25973                                 255                        18-21
#
#                                            Q2  \
# 0      What is your gender? - Selected Choice
# ...

# %%
survey_df.isnull().sum().sort_values(ascending=False)
# Out:
# Q38_B_Part_11                          25973
# Q37_B_Part_7                           25973
# Q31_B_Part_9                           25973
# Q30_B_Part_6                           25973
# Q30_B_Part_7                           25973
#                                        ...
# Q6                                         0
# Q4                                         0
# Q3                                         0
# Time from Start to Finish (seconds)        0
# Q2                                         0
# Length: 369, dtype: int64

# %%
duplicated_mask = survey_df.columns.duplicated(keep='first')
non_duplicated_columns = [col for col, is_dup in zip(survey_df.columns, duplicated_mask) if not is_dup]
survey_df = survey_df[non_duplicated_columns]
print(survey_df)
# Out:
#       Time from Start to Finish (seconds)                           Q1  \
# 0                   Duration (in seconds)  What is your age (# years)?
# 1                                     910                        50-54
# 2                                     784                        50-54
# 3                                     924                        22-24
# 4                                     575                        45-49
# ...                                   ...                          ...
# 25969                                1756                        30-34
# 25970                                 253                        22-24
# 25971                                 494                        50-54
# 25972                                 277                        45-49
# 25973                                 255                        18-21
#
#                                            Q2  \
# 0      What is your gender? - Selected Choice
# ...

# %%
type(survey_df)
# Out:
# pandas.core.frame.DataFrame

# %%
survey_df.rename(columns = {'Q1':'age',
                            'Q2':'gender',
                            'Q3':'location',
                            'Q4':'education level',
                            'Q5':'job title',
                            'Q6':'years of experience',
                            'Q7_Part_1':'Python',
                            'Q7_Part_2':'R',
                            'Q7_Part_3':'SQL',
                            'Q7_Part_4':'C',
                            'Q7_Part_5':'C++',
                            'Q7_Part_6': 'Java',
                            'Q7_Part_7': 'Javascript',
                            'Q7_Part_8': 'Julia',
                            'Q7_Part_9': 'Swift',
                            'Q7_Part_10': 'Bash',
                            'Q7_Part_11': 'MATLAB',
                            'Q7_Part_12': 'None'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 survey_df.rename(columns = {'Q1':'age',
#       2                             'Q2':'gender',
#       3                             'Q3':'location',
#       4                             'Q4':'education level',
#       5                             'Q5':'job title',
#       6                             'Q6':'years of experience',
#       7                             'Q7_Part_1':'Python',
#       8                             'Q7_Part_2':'R',
#       9                             'Q7_Part_3':'SQL',
#      10                             'Q7_Part_4':'C',
#      11                             'Q7_Part_5':'C++',
#      12                             'Q7_Part_6': 'Java',
#      13                             'Q7_Part_7': 'Javascript',
#      14                             'Q7_Part_8': 'Julia',
# ...

# %%
kaggle kernels output priyharshgangwar/competitive-constellations-kaggle-s-kernels -p /path/to/dest
# Out:
#   Cell In[3], line 1
#     kaggle kernels output priyharshgangwar/competitive-constellations-kaggle-s-kernels -p /path/to/dest
#            ^
# SyntaxError: invalid syntax
